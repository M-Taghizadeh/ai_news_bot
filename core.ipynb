# %%
import pandas as pd

df = pd.read_csv("ai_news_bot/news_content.csv")

# %% [markdown]
# # Summarizer

# %%
# ! pip install nltk, scikit-learn
# nltk.download('punkt')

# %%
import nltk
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def summarize_text(text, num_sentences=2):
    sentences = sent_tokenize(text)
    vectorizer = CountVectorizer().fit_transform(sentences)
    vectors = vectorizer.toarray()
    similarity_matrix = cosine_similarity(vectors)
    scores = similarity_matrix.sum(axis=1)
    ranked_sentences = [sentences[i] for i in scores.argsort()[-num_sentences:]]
    summarized_text = ' '.join(ranked_sentences)
    return summarized_text

# %%
news_dict = {'title': [], 'url': [], 'content': [], 'content_summary': [], 'thumbnail': [], 'publish_date': []}
number_of_news = len(df['title'])
number_of_news = 10

for i in range(0, number_of_news):
    row = df.iloc[i]
    content = row['content']
    content_summary = summarize_text(content, num_sentences=5)

    news_dict['title'].append(row['title'])
    news_dict['url'].append(row['url'])
    news_dict['content'].append(content)
    news_dict['content_summary'].append(content_summary)
    news_dict['thumbnail'].append(row['thumbnail'])
    news_dict['publish_date'].append(row['publish_date'])

# %%
news_df = pd.DataFrame(news_dict)

# %% [markdown]
# # Translator

# %%
import googletrans

news_dict = {'title': [], 'title_fa': [], 'url': [], 'content': [], 'content_fa': [], 'thumbnail': [], 'publish_date': []}
number_of_news = len(df['title'])
number_of_news = 10

for i in range(0, number_of_news):
    row = df.iloc[i]
    title = row['title']
    content = row['content']

    try:
        # translate content
        translator = googletrans.Translator()
        title_fa = translator.translate(title, src='en', dest='fa')
        content_fa = translator.translate(content, src='en', dest='fa')

        news_dict['title'].append(title)
        news_dict['title_fa'].append(title_fa.text)
        news_dict['url'].append(row['url'])
        news_dict['content'].append(content)
        news_dict['content_fa'].append(content_fa.text)
        news_dict['thumbnail'].append(row['thumbnail'])
        news_dict['publish_date'].append(row['publish_date'])
    except: print("error")
# Out:
# error

# %%
news_df = pd.DataFrame(news_dict)
news_df
# Out:
#                                                title  \
# 0  The Perception of Beauty Varies, but Memorabil...
# 1  An Insight into Our Strategy for Ensuring AI S...
# 2  ‘Bing Chat by Microsoft Being Tested for ‘Sele...
# 3  The Potential of AI in Promoting Equality in H...
# 4           OpenAI Introduces New Bug Bounty Program
# 5  Why Hollywood Strikes Reveal Our Distrust in C...
# 6  Google Health Officer Urges Caution About AI’s...
# 7        Desire Grows for Ukraine’s Battlefield Data
# 8  Artificial Intelligence Stocks Experience Soar...
#
#                                             title_fa  \
# 0  درک زیبایی متفاوت است ، اما به یاد ماندنی هیچ ...
# 1  بینشی از استراتژی ما برای اطمینان از ایمنی هوش...
# 2  "چت بینگ توسط مایکروسافت برای" انتخاب کاربران ...
# 3  پتانسیل هوش مصنوعی در ارتقاء برابری در مراقبت ...
# 4   OpenAI برنامه جدید Bounty Bounty را معرفی می کند
# 5  چرا اعتصابات هالیوود بی اعتمادی ما را به شرکته...
# 6  افسر بهداشت گوگل در مورد محدودیت های هوش مصنوع...
# 7  Desire برای داده های میدان نبرد اوکراین رشد می...
# 8  سهام هوش مصنوعی عملکرد بالایی را تجربه می کند ...
#
#                                                  url  \
# 0  https://ainewstoday.co.uk/2023/07/25/the-perce...
# 1  https://ainewstoday.co.uk/2023/07/25/an-insigh...
# 2  https://ainewstoday.co.uk/2023/07/25/bing-chat...
# 3  https://ainewstoday.co.uk/2023/07/24/the-poten...
# 4  https://ainewstoday.co.uk/2023/07/24/openai-in...
# 5  https://ainewstoday.co.uk/2023/07/24/why-holly...
# 6  https://ainewstoday.co.uk/2023/07/24/google-he...
# 7  https://ainewstoday.co.uk/2023/07/24/desire-gr...
# 8  https://ainewstoday.co.uk/2023/07/24/artificia...
#
#                                              content  \
# 0  Imagine spending a weekend afternoon with frie...
# 1  OpenAI, the artificial intelligence (AI) resea...
# 2  Microsoft has confirmed that its AI chatbot, B...
# 3  Marzyeh Ghassemi, an Assistant Professor at CS...
# 4  In its ongoing effort to create safe and secur...
# 5  History suggests that societies generally over...
# 6  Google’s chief health officer, Dr Karen DeSalv...
# 7  In recent months, Ukraine has been vocal about...
# 8  US tech companies were facing a challenging st...
#
#                                           content_fa  \
# 0  تصور کنید که یک بعد از ظهر آخر هفته را با دوست...
# 1  Openai ، آزمایشگاه تحقیقاتی هوش مصنوعی (AI) ، ...
# 2  مایکروسافت تأیید کرده است که AI Chatbot آن ، B...
# 3  مارزی قسممی ، استادیار در CSAIL ، IMES و EECS ...
# 4  Openai در تلاش مداوم خود برای ایجاد سیستم های ...
# 5  تاریخ نشان می دهد که جوامع به طور کلی پیامدهای...
# 6  مدیر ارشد بهداشت Google ، دکتر کارن دزالو ، هم...
# 7  در ماه های اخیر ، اوکراین در مورد برنامه های خ...
# 8  شرکت های فناوری ایالات متحده با شروع سال چالش ...
#
#                                            thumbnail publish_date
# 0  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-25
# 1  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-25
# 2  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-25
# 3  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-24
# 4  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-24
# 5  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-24
# 6  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-24
# 7  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-24
# 8  https://ainewstoday.co.uk/wp-content/uploads/2...   2023-07-24
