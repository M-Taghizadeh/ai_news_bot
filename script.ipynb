# %%
import pandas as pd

df = pd.read_csv('results.csv')
df
# Out:
#      Unnamed: 0                                              title  \
# 0             0                                     \r\n\t\t\t\t\t
# 1             1  Mission: Impossible – Dead Reckoning Is the Pe...
# 2             2                                          Read More
# 3             3                                     \r\n\t\t\t\t\t
# 4             4              Cybersecurity Grant Program by OpenAI
# ..          ...                                                ...
# 214         214  Enhancing Mathematical Reasoning through Proce...
# 215         215                                          Read More
# 216         216                                     \r\n\t\t\t\t\t
# 217         217  Unleashing the Potential of AI on Windows 11: ...
# 218         218                                          Read More
#
#                                                   link
# 0    https://ainewstoday.co.uk/2023/07/15/mission-i...
# ...

# %%
list(df['link'])
# Out:
# ['https://ainewstoday.co.uk/2023/07/15/mission-impossible-dead-reckoning-is-the-perfect-ai-panic-movie/',
#  'https://ainewstoday.co.uk/2023/07/15/mission-impossible-dead-reckoning-is-the-perfect-ai-panic-movie/',
#  'https://ainewstoday.co.uk/2023/07/15/mission-impossible-dead-reckoning-is-the-perfect-ai-panic-movie/',
#  'https://ainewstoday.co.uk/2023/07/15/cybersecurity-grant-program-by-openai/',
#  'https://ainewstoday.co.uk/2023/07/15/cybersecurity-grant-program-by-openai/',
#  'https://ainewstoday.co.uk/2023/07/15/cybersecurity-grant-program-by-openai/',
#  'https://ainewstoday.co.uk/2023/07/15/tech-layoffs-enter-the-pruning-phase/',
#  'https://ainewstoday.co.uk/2023/07/15/tech-layoffs-enter-the-pruning-phase/',
#  'https://ainewstoday.co.uk/2023/07/15/tech-layoffs-enter-the-pruning-phase/',
#  'https://ainewstoday.co.uk/2023/07/15/generative-ai-leaps-forward-with-pinecones-major-advancements-in-vector-databases/',
# ...

# %%
my_dict = [
    {"title": "مطلب اول", "url": "www.example.com/1", "date": "2023-07-20"},
    {"title": "مطلب دوم", "url": "www.example.com/2", "date": "2023-07-23"},
    {"title": "مطلب سوم", "url": "www.example.com/3", "date": "2023-07-18"},
]

sorted_dict = sorted(my_dict, key=lambda x: x["date"])

# %%
pandas.concat([df1,df2]).drop_duplicates().reset_index(drop=True)
# Out:
# [{'title': 'مطلب سوم', 'url': 'www.example.com/3', 'date': '2023-07-18'},
#  {'title': 'مطلب اول', 'url': 'www.example.com/1', 'date': '2023-07-20'},
#  {'title': 'مطلب دوم', 'url': 'www.example.com/2', 'date': '2023-07-23'}]

# %%
import pandas as pd 

df_1 = pd.DataFrame([
{'date':'11/20/2015', 'id':4, 'value':24},
{'date':'11/20/2015', 'id':4, 'value':24},
{'date':'11/20/2015', 'id':6, 'value':34},])

df_2 = pd.DataFrame([
{'date':'11/20/2015', 'id':4, 'value':24},
{'date':'11/20/2015', 'id':6, 'value':14},
])

pd.concat([df_1,df_2]).drop_duplicates().reset_index(drop=True)
# Out:
#          date  id  value
# 0  11/20/2015   4     24
# 1  11/20/2015   6     34
# 2  11/20/2015   6     14

# %%
import googletrans
translator = googletrans.Translator()
result = translator.translate('Hello', src='en', dest='fa')

# %%
pip install textblob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import nltk
#       2 nltk.download('punkt')
#       3 from nltk.tokenize import sent_tokenize
#
# ModuleNotFoundError: No module named 'nltk'
